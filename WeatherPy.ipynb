# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from citipy import citipy  

# Import API key
from api_keys import weather_api_key

# File (CSV)
data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
lat_lngs = []
cities = []

lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 622

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#OpenWeather Key
api_key = weather_api_key
units = "imperial"

url = f"http://api.openweathermap.org/data/2.5/weather?appid={api_key}&units={units}&q="

print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=beb9cd7f4c99ca79537d7299fc304851&units=imperial&q=

# %%
city_two = []
cloudinesses = []
dates = []
humidities = []
lats = []
lngs = []
max_temps = []
wind_speeds = []
countries = []

count_one = 0
set_one = 1

# loops for creating dataframe columns
for city in cities:
    try:
        response = requests.get(url + city.replace(" ","&")).json()
        cloudinesses.append(response['clouds']['all'])
        countries.append(response['sys']['country'])
        dates.append(response['dt'])
        humidities.append(response['main']['humidity'])
        lats.append(response['coord']['lat'])
        lngs.append(response['coord']['lon'])
        max_temps.append(response['main']['temp_max'])
        wind_speeds.append(response['wind']['speed'])
        if count_one > 48:
            count_one = 1
            set_one += 1
            city_two.append(city)
        else:
            count_one += 1
            city_two.append(city)
        print(f"City {count_one} of Set {set_one} | {city}")
    except Exception:
        print("City not found. Skipping...")
# Out:
# City 1 of Set 1 | hermiston
# City 2 of Set 1 | nishihara
# City 3 of Set 1 | ushuaia
# City 4 of Set 1 | kawalu
# City 5 of Set 1 | inuvik
# City 6 of Set 1 | naze
# City 7 of Set 1 | port hedland
# City 8 of Set 1 | geraldton
# City 9 of Set 1 | lompoc
# City 10 of Set 1 | kapaa
# City not found. Skipping...
# City 11 of Set 1 | aripuana
# City 12 of Set 1 | narsaq
# City 13 of Set 1 | rikitea
# City not found. Skipping...
# City 14 of Set 1 | port lincoln
# City 15 of Set 1 | harper
# City 16 of Set 1 | tautira
# City 17 of Set 1 | saint-philippe
# City 18 of Set 1 | kashan
# City 19 of Set 1 | yumen
# City 20 of Set 1 | constitucion
# City not found. Skipping...
# City 21 of Set 1 | arrecife
# City 22 of Set 1 | thompson
# City 23 of Set 1 | victoria
# City 24 of Set 1 | strezhevoy
# City 25 of Set 1 | baglung
# City 26 of Set 1 | ancud
# City 27 of Set 1 | mataura
# City 28 of Set 1 | cape town
# City 29 of Set 1 | albany
# City 30 of Set 1 | provideniya
# City 31 of Set 1 | tabou
# City 32 of Set 1 | haimen
# City 33 of Set 1 | longyearbyen
# City 34 of Set 1 | hasaki
# City 35 of Set 1 | airai
# City 36 of Set 1 | kutum
# City 37 of Set 1 | majene
# City 38 of Set 1 | vostok
# City not found. Skipping...
# City 39 of Set 1 | caravelas
# City 40 of Set 1 | kaitangata
# City not found. Skipping...
# City 41 of Set 1 | hobart
# City 42 of Set 1 | puerto ayora
# City 43 of Set 1 | nyurba
# City 44 of Set 1 | new norfolk
# City 45 of Set 1 | caico
# City not found. Skipping...
# City not found. Skipping...
# City 46 of Set 1 | khatanga
# City not found. Skipping...
# City 47 of Set 1 | punta arenas
# City 48 of Set 1 | esperance
# City 49 of Set 1 | bell ville
# City not found. Skipping...
# City 1 of Set 2 | barrow
# City 9 of Set 5 | faya
# City 10 of Set 5 | pangai
# City 11 of Set 5 | fairbanks
# City 12 of Set 5 | chern
# City 13 of Set 5 | isangel
# City 14 of Set 5 | riyadh
# City not found. Skipping...
# City 15 of Set 5 | kulhudhuffushi
# City 16 of Set 5 | champerico
# City 17 of Set 5 | klaksvik
# City 18 of Set 5 | bengkulu
# City 19 of Set 5 | sirur
# City 20 of Set 5 | kruisfontein
# City 21 of Set 5 | saskylakh
# City 22 of Set 5 | noumea
# City 23 of Set 5 | pinos
# City 24 of Set 5 | dingle
# City 25 of Set 5 | cosala
# City 26 of Set 5 | ferrol
# City 27 of Set 5 | dovbysh
# City 28 of Set 5 | mocorito
# City 29 of Set 5 | alamosa
# City not found. Skipping...
# City not found. Skipping...
# City 30 of Set 5 | sola
# City not found. Skipping...
# City 31 of Set 5 | grand centre
# City 32 of Set 5 | fraserburgh
# City 33 of Set 5 | krasnystaw
# City 34 of Set 5 | beringovskiy
# City 35 of Set 5 | atherton
# City 36 of Set 5 | wahiawa
# City 37 of Set 5 | olavarria
# City 38 of Set 5 | male
# City not found. Skipping...
# City 39 of Set 5 | sorland
# City 40 of Set 5 | sistranda
# City 41 of Set 5 | norman wells
# City not found. Skipping...
# City 42 of Set 5 | bilibino
# City 43 of Set 5 | bac lieu
# City 44 of Set 5 | adrar
# City 45 of Set 5 | chuy
# City 46 of Set 5 | ponta do sol
# City 47 of Set 5 | ndago
# City 48 of Set 5 | dunedin
# City 49 of Set 5 | nhulunbuy
# City 1 of Set 6 | sumter
# City not found. Skipping...
# City 2 of Set 6 | abadiania
# City 3 of Set 6 | nome
# City 4 of Set 6 | tessalit
# City 5 of Set 6 | ponta delgada
# City 6 of Set 6 | butaritari
# City 7 of Set 6 | sebinkarahisar
# City 8 of Set 6 | nikki
# City 9 of Set 6 | nelson bay
# City 10 of Set 6 | tiksi
# City 11 of Set 6 | damara
# City 12 of Set 6 | beian
# City 13 of Set 6 | dolores
# City not found. Skipping...
# City 14 of Set 6 | rockhampton
# City 15 of Set 6 | huescar
# City 16 of Set 6 | omboue
# City 17 of Set 6 | jalu
# City 18 of Set 6 | padang
# City 19 of Set 6 | port hardy
# City 20 of Set 6 | ulaangom
# City 21 of Set 6 | san patricio
# City 22 of Set 6 | ranfurly
# City 23 of Set 6 | chokurdakh
# City 24 of Set 6 | sibolga
# City 25 of Set 6 | mocuba
# City 26 of Set 6 | svetlyy
# City 27 of Set 6 | masallatah
# City 28 of Set 6 | faanui
# City 29 of Set 6 | pata
# City 30 of Set 6 | schneverdingen
# City 31 of Set 6 | kodiak
# City 32 of Set 6 | clyde river
# City 33 of Set 6 | chengde
# City 34 of Set 6 | belmonte
# City 35 of Set 6 | mahebourg
# City 36 of Set 6 | san rafael
# City 37 of Set 6 | srednekolymsk
# City 38 of Set 6 | solnechnyy
# City 39 of Set 6 | pacocha
# City 40 of Set 6 | khandyga
# City 23 of Set 8 | godim
# City 24 of Set 8 | mporokoso
# City not found. Skipping...
# City 25 of Set 8 | moosburg
# City 26 of Set 8 | guanica
# City not found. Skipping...
# City 27 of Set 8 | kauhajoki
# City 28 of Set 8 | linhai
# City 29 of Set 8 | santa rosa
# City 30 of Set 8 | mizdah
# City 31 of Set 8 | tiruchchendur
# City 32 of Set 8 | thiruvananthapuram
# City 33 of Set 8 | solotcha
# City 34 of Set 8 | fort nelson
# City 35 of Set 8 | buraydah
# City 36 of Set 8 | lafia
# City 37 of Set 8 | santo tomas
# City 38 of Set 8 | inhambane
# City 39 of Set 8 | khowst
# City 40 of Set 8 | pevek
# City 41 of Set 8 | lixourion
# City 42 of Set 8 | methven
# City not found. Skipping...
# City 43 of Set 8 | xuanhua
# City 44 of Set 8 | cayenne
# City 45 of Set 8 | vestmanna
# City 46 of Set 8 | belton
# City 47 of Set 8 | akdepe
# City 48 of Set 8 | myskhako
# City 49 of Set 8 | acarau
# City 1 of Set 9 | davila
# City 2 of Set 9 | huesca
# City 3 of Set 9 | tadine
# City 4 of Set 9 | zyryanka
# City 5 of Set 9 | grants
# City 6 of Set 9 | puerto madryn
# City 7 of Set 9 | soyaux
# City 8 of Set 9 | tura
# City 9 of Set 9 | northam
# City 10 of Set 9 | high level
# City 11 of Set 9 | vao
# City 12 of Set 9 | aksarka
# City 13 of Set 9 | hovd
# City 14 of Set 9 | visnes
# City 15 of Set 9 | yulara
# City not found. Skipping...
# City 16 of Set 9 | tucupita
# City 17 of Set 9 | skjervoy
# City 18 of Set 9 | biak
# City 19 of Set 9 | cururupu
# City not found. Skipping...
# City 20 of Set 9 | tigil
# City not found. Skipping...
# City 21 of Set 9 | taltal
# City 22 of Set 9 | gainesville
# City 23 of Set 9 | pokhara
# City 24 of Set 9 | merauke
# City 25 of Set 9 | guilin
# City 26 of Set 9 | riverton
# City 27 of Set 9 | borgarnes
# City 28 of Set 9 | mongoumba
# City not found. Skipping...
# City 29 of Set 9 | santarem
# City 30 of Set 9 | pemberton
# City 31 of Set 9 | edinet
# City 32 of Set 9 | ovsyanka
# City 33 of Set 9 | kokopo
# City not found. Skipping...
# City 34 of Set 9 | turukhansk
# City 35 of Set 9 | praya
# City not found. Skipping...
# City 36 of Set 9 | lakes entrance
# City 37 of Set 9 | torrington
# City 38 of Set 9 | saraza
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City 39 of Set 9 | mujiayingzi
# City 40 of Set 9 | salinopolis
# City 41 of Set 9 | benghazi
# City 42 of Set 9 | syamzha
# City 43 of Set 9 | lata
# City 44 of Set 9 | libertador general san martin
# City 45 of Set 9 | karratha
# City 46 of Set 9 | goya
# City 47 of Set 9 | ribeirao branco
# City not found. Skipping...
# City 48 of Set 9 | namatanai
# City 49 of Set 9 | cockburn town
# City 1 of Set 10 | sabang
# City 2 of Set 10 | havre-saint-pierre
# City 3 of Set 10 | de-kastri
# City 4 of Set 10 | whitecourt
# City 5 of Set 10 | husavik
# City 6 of Set 10 | katsuura
# City 7 of Set 10 | koygorodok
# City 8 of Set 10 | chaiyaphum
# City 9 of Set 10 | aswan
# City not found. Skipping...
# City 10 of Set 10 | stephenville
# City 11 of Set 10 | xuddur
# City 12 of Set 10 | hamilton
# City 13 of Set 10 | bad neustadt
# City 14 of Set 10 | caldas novas
# City 15 of Set 10 | tomakomai
# City 16 of Set 10 | george
# City 17 of Set 10 | cochrane
# City 18 of Set 10 | bhandaria
# City 19 of Set 10 | wonthaggi
# City 20 of Set 10 | bonavista
# City 21 of Set 10 | huambo
# City 22 of Set 10 | meulaboh
# City 23 of Set 10 | sterling
# City 24 of Set 10 | krasnoselkup
# City 25 of Set 10 | bontang
# City 26 of Set 10 | cabacungan
# City 27 of Set 10 | cortland
# City 28 of Set 10 | akyab
# City not found. Skipping...
# City 29 of Set 10 | rio cuarto
# City 30 of Set 10 | agirish
# City 31 of Set 10 | sibu
# City 32 of Set 10 | asfi
# City 33 of Set 10 | ushtobe
# City 34 of Set 10 | shimoda
# City 35 of Set 10 | aketi
# City 36 of Set 10 | marrakesh
# City 37 of Set 10 | bani walid
# City 38 of Set 10 | beja
# City 39 of Set 10 | sao filipe
# City 40 of Set 10 | thornbury
# City 41 of Set 10 | gazojak
# City 42 of Set 10 | belaya kholunitsa
# City not found. Skipping...
# City not found. Skipping...
# City 43 of Set 10 | nakamura
# City 44 of Set 10 | kenai
# City 45 of Set 10 | hinova
# City 46 of Set 10 | benjamin aceval
# City 47 of Set 10 | dergachi
# City 48 of Set 10 | sisimiut
# City 49 of Set 10 | mouila
# City 1 of Set 11 | ukiah
# City 2 of Set 11 | ruma
# City 3 of Set 11 | grindavik
# City 4 of Set 11 | svilengrad
# City 5 of Set 11 | samarai
# City 6 of Set 11 | san ignacio de sabaneta
# City 7 of Set 11 | leh
# City not found. Skipping...
# City 8 of Set 11 | yar-sale
# City 9 of Set 11 | price
# City 10 of Set 11 | campo grande
# City 11 of Set 11 | lufilufi
# City 12 of Set 11 | birjand
# City 13 of Set 11 | dourbali
# City 14 of Set 11 | hami
# City 15 of Set 11 | kimberley
# City 16 of Set 11 | nemuro
# City 17 of Set 11 | tamandare
# City 18 of Set 11 | kidal
# City 19 of Set 11 | kijang
# City 20 of Set 11 | manzhouli
# City 21 of Set 11 | rio gallegos
# City 22 of Set 11 | kristiansund
# City 23 of Set 11 | lazarev
# City 24 of Set 11 | nguru
# City 25 of Set 11 | ibra
# City 26 of Set 11 | abu dhabi
# City 27 of Set 11 | beaufort
# City not found. Skipping...
# City 28 of Set 11 | hervey bay
# City 29 of Set 11 | olenino
# City 30 of Set 11 | lichinga
# City not found. Skipping...
# City 31 of Set 11 | boa vista
# City 32 of Set 11 | khor
# City 33 of Set 11 | boyolangu
# City not found. Skipping...
# City 34 of Set 11 | baoning
# City 35 of Set 11 | mayo
# City 36 of Set 11 | kisumu
# City 37 of Set 11 | kudat
# City 38 of Set 11 | haverfordwest
# City 39 of Set 11 | sargatskoye
# City 40 of Set 11 | sur
# City 41 of Set 11 | vanimo
# City 42 of Set 11 | deputatskiy
# City 43 of Set 11 | esfarayen
# City 44 of Set 11 | ust-kuyga
# City 45 of Set 11 | luan
# City 46 of Set 11 | kautokeino
# City 47 of Set 11 | tambura
# City 48 of Set 11 | madison
# City 49 of Set 11 | mercedes
# City 1 of Set 12 | sept-iles
# City not found. Skipping...
# City 2 of Set 12 | flagstaff
# City 3 of Set 12 | kamenka
# City 4 of Set 12 | tevaitoa
# City 5 of Set 12 | gladstone
# City 6 of Set 12 | san cristobal
# City 7 of Set 12 | luganville
# City 8 of Set 12 | katima mulilo

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Data Frame
weather_dict = {
    "City": city_two,
    "Cloudiness": cloudinesses,
    "Country": countries,
    "Date": dates,
    "Humidity": humidities,
    "Lat": lats,
    "Lng": lngs,
    "Max Temp": max_temps,
    "Wind Speed": wind_speeds
}

weather_df = pd.DataFrame(weather_dict)

# Exporting to CSV
weather_df.to_csv("weather_df.csv")

weather_data = pd.read_csv("weather_df.csv")

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#Create a Scatter Plot for Lattitude vs Temperature of City
plt.scatter(weather_df["Lat"], weather_df["Max Temp"], marker='o',s=30, edgecolors= "black")
plt.title("City Latitude vs Max Temperature")
plt.ylim(-40,110)
plt.xlim(-60, 100)
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid()
# plt.show()

plt.savefig("LAT VS TEMP.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
#create a Scatter Plot for Lattitude vs Humidity
plt.scatter(weather_df["Lat"], weather_df["Humidity"], marker='o', s=30, edgecolors= "black")
plt.title("City Latitude vs Humidity")
plt.ylim(-40,150)
plt.xlim(-60, 100)
plt.ylabel("Humidity Level (%)")
plt.xlabel("Latitude")
plt.grid()
# plt.show()

plt.savefig('LAT VS HUM.png')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], marker='o', s=30, edgecolors= "black")
plt.title("City Latitude vs Cloudiness")
plt.ylim(-10,110)
plt.xlim(-60, 100)
plt.ylabel("Cloudiness Level (%)")
plt.xlabel("Latitude")
plt.grid()
# plt.show()

plt.savefig('LAT VS CLOUD.png')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], marker='o', s=30, edgecolors= "black")
plt.title("City Latitude vs Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid()
# plt.show()

plt.savefig('LAT VS WIND.png')

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere = weather_df.loc[weather_df["Lat"]>0.01]
southern_hemisphere = weather_df.loc[weather_df["Lat"]<-0.01]

# northern_hemisphere.head()
# southern_hemisphere.head()

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Create a Scatter Plot for Lattitude vs Temperature of City
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"red")
plt.annotate(line_eq,(5,10),fontsize=15,color="red")

plt.ylim(0,100)
plt.xlim(0, 80)

plt.ylabel("Max. Temp")
plt.xlabel("Latitude")
# plt.show()

plt.savefig("NORTH MAX TEMP VS LAT.png")

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#Create a Scatter Plot for Lattitude vs Temperature of City (Southern Hemisphere)
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"red")
plt.annotate(line_eq,(5,10),fontsize=10,color="red")

plt.ylim(30, 100)
plt.xlim(-60, 10)

plt.ylabel("Max. Temp")
plt.xlabel("Latitude")
# plt.show()

plt.savefig("SOUTH MAX TEMP VS LAT.png")

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
# plt.show()

plt.savefig("NORTH HUM VS LAT.png")

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-25,10),fontsize=15,color="red")

plt.ylim(0, 100)

plt.ylabel("Humidity")
plt.xlabel("Latitude")
# plt.show()

plt.savefig("SOUTH HUM VS LAT.png")

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
# plt.show()

plt.savefig("NORTH CLOUD VS LAT.png")

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-25,10),fontsize=15,color="red")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
# plt.show()

plt.savefig("SOUTH CLOUD VS LAT.png")

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_hemisphere['Lat']
y_values = northern_hemisphere['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(45,22),fontsize=15,color="red")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
# plt.show()

plt.savefig("NORTH WIND VS LAT.png")

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_hemisphere['Lat']
y_values = southern_hemisphere['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-25,25),fontsize=15,color="red")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
# plt.show()

plt.savefig("SOUTH WIND VS LAT.png")
